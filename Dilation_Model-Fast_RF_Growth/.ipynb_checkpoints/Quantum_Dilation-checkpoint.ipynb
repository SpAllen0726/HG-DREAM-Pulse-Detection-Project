# %%
import os
import numpy as np

import qkeras
from qkeras import QActivation
from qkeras import QConv1D
from qkeras.quantizers import quantized_bits, quantized_relu, quantized_tanh

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, UpSampling1D, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger



resolution = 150
X_total = np.load(f"Data/X_Data_Bank_{resolution}.npy")
Y_total = np.load(f"Data/Y_Data_Bank_{resolution}.npy")
X_data = X_total[:1500,:,:]
y_data = Y_total[:1500,:,:]
TIME_STEPS = np.shape(X_data)[1]

VAL_SPLIT = 0.1

SAVE_DIR_opt = '1Conv_checkpoints_running_opt'
LOG_FILE_opt = '1Conv_3pulse_noise_tb23_opt.csv'
MODEL_NAME_TEMPLATE_opt = '1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv_opt.h5'
checkpoint_path_opt = os.path.join(SAVE_DIR_opt, MODEL_NAME_TEMPLATE_opt)


wq = quantized_bits(8, 2, alpha=1) 
aq = quantized_relu(6) 

qmodel = Sequential([
    Input(shape=(TIME_STEPS, 1)),

    QConv1D(32, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    QConv1D(32, 3, strides=2, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    QConv1D(64, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    UpSampling1D(2),

    QConv1D(32, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),
    
    QConv1D(1, 1, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    
    QActivation("quantized_sigmoid")
    ])

qmodel.summary()


optimizer = Adam(learning_rate=0.001)
qmodel.compile(loss='binary_crossentropy', optimizer=optimizer) 


if not os.path.isdir(SAVE_DIR_opt):
    os.makedirs(SAVE_DIR_opt)

callbacks = [
    ModelCheckpoint(checkpoint_path_opt, monitor="val_loss", save_best_only=True, mode="min", verbose=1),
    CSVLogger(LOG_FILE_opt, append=True, separator=','),
    EarlyStopping(monitor="val_loss", mode="min", patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1) 
]


qmodel.fit(
    X_data, y_data,
    epochs=150,                  
    shuffle=True,
    validation_split=VAL_SPLIT,
    callbacks=callbacks,
)

if not os.path.isdir("hgdream_new"):
    os.makedirs("hgdream_new")
    
qmodel.save(f"hgdream_new/quantized_model_opt_{resolution}.h5")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_conv1d_10 (QConv1D)       (None, 80, 32)            128
#
#  q_activation_10 (QActivatio  (None, 80, 32)           0
#  n)
#
#  q_conv1d_11 (QConv1D)       (None, 40, 32)            3104
#
#  q_activation_11 (QActivatio  (None, 40, 32)           0
#  n)
#
#  q_conv1d_12 (QConv1D)       (None, 40, 64)            6208
#
#  q_activation_12 (QActivatio  (None, 40, 64)           0
#  n)
#
#  up_sampling1d_2 (UpSampling  (None, 80, 64)           0
#  1D)
#
#  q_conv1d_13 (QConv1D)       (None, 80, 32)            6176
#
#  q_activation_13 (QActivatio  (None, 80, 32)           0
#  n)
#
#  q_conv1d_14 (QConv1D)       (None, 80, 1)             33
#
#  q_activation_14 (QActivatio  (None, 80, 1)            0
#  n)
#
# =================================================================
# Total params: 15,649
# Trainable params: 15,649
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.2968
# Epoch 1: val_loss improved from inf to 0.15514, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.15514.e001_deconv_opt.h5
# 43/43 [==============================] - 1s 9ms/step - loss: 0.2598 - val_loss: 0.1551 - lr: 0.0010
# Epoch 2/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1539
# Epoch 2: val_loss improved from 0.15514 to 0.14976, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.14976.e002_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1500 - val_loss: 0.1498 - lr: 0.0010
# Epoch 3/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1432
# Epoch 3: val_loss improved from 0.14976 to 0.14345, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.14345.e003_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1450 - val_loss: 0.1434 - lr: 0.0010
# Epoch 4/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1403
# Epoch 4: val_loss improved from 0.14345 to 0.13957, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.13957.e004_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1413 - val_loss: 0.1396 - lr: 0.0010
# Epoch 5/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1362
# Epoch 5: val_loss improved from 0.13957 to 0.13068, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.13068.e005_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1354 - val_loss: 0.1307 - lr: 0.0010
# Epoch 6/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1318
# Epoch 6: val_loss improved from 0.13068 to 0.12960, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12960.e006_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1324 - val_loss: 0.1296 - lr: 0.0010
# Epoch 7/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1331
# Epoch 7: val_loss did not improve from 0.12960
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1326 - val_loss: 0.1305 - lr: 0.0010
# Epoch 8/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1292
# Epoch 8: val_loss did not improve from 0.12960
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1322 - val_loss: 0.1675 - lr: 0.0010
# Epoch 9/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1331
# Epoch 9: val_loss improved from 0.12960 to 0.12776, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12776.e009_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1309 - val_loss: 0.1278 - lr: 0.0010
# Epoch 10/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1265
# Epoch 10: val_loss did not improve from 0.12776
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1270 - val_loss: 0.1312 - lr: 0.0010
# Epoch 11/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1273
# Epoch 11: val_loss improved from 0.12776 to 0.12568, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12568.e011_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1270 - val_loss: 0.1257 - lr: 0.0010
# Epoch 12/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1268
# Epoch 12: val_loss improved from 0.12568 to 0.12508, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12508.e012_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1270 - val_loss: 0.1251 - lr: 0.0010
# Epoch 13/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1269
# Epoch 13: val_loss did not improve from 0.12508
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1256 - val_loss: 0.1313 - lr: 0.0010
# Epoch 14/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1249
# Epoch 14: val_loss did not improve from 0.12508
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1242 - val_loss: 0.1271 - lr: 0.0010
# Epoch 15/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1260
# Epoch 15: val_loss did not improve from 0.12508
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1250 - val_loss: 0.1254 - lr: 0.0010
# Epoch 16/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1229
# Epoch 16: val_loss did not improve from 0.12508
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1232 - val_loss: 0.1275 - lr: 0.0010
# Epoch 17/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1204
# Epoch 17: val_loss did not improve from 0.12508
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1220 - val_loss: 0.1311 - lr: 0.0010
# Epoch 18/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1191
# Epoch 18: val_loss improved from 0.12508 to 0.12332, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12332.e018_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1212 - val_loss: 0.1233 - lr: 5.0000e-04
# Epoch 19/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1225
# Epoch 19: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1209 - val_loss: 0.1262 - lr: 5.0000e-04
# Epoch 20/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1190
# Epoch 20: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1203 - val_loss: 0.1261 - lr: 5.0000e-04
# Epoch 21/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1213
# Epoch 21: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1212 - val_loss: 0.1289 - lr: 5.0000e-04
# Epoch 22/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1165
# Epoch 22: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1195 - val_loss: 0.1260 - lr: 5.0000e-04
# Epoch 23/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1188
# Epoch 23: val_loss did not improve from 0.12332
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1196 - val_loss: 0.1243 - lr: 5.0000e-04
# Epoch 24/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1175
# Epoch 24: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1194 - val_loss: 0.1292 - lr: 2.5000e-04
# Epoch 25/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1189
# Epoch 25: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1192 - val_loss: 0.1292 - lr: 2.5000e-04
# Epoch 26/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1182
# Epoch 26: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1195 - val_loss: 0.1259 - lr: 2.5000e-04
# Epoch 27/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1184
# Epoch 27: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1183 - val_loss: 0.1306 - lr: 2.5000e-04
# Epoch 28/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1199
# Epoch 28: val_loss did not improve from 0.12332
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1189 - val_loss: 0.1287 - lr: 2.5000e-04
# Epoch 29/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1184
# Epoch 29: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1183 - val_loss: 0.1249 - lr: 1.2500e-04
# Epoch 30/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1184
# Epoch 30: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1182 - val_loss: 0.1317 - lr: 1.2500e-04
# Epoch 31/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1180
# Epoch 31: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1181 - val_loss: 0.1252 - lr: 1.2500e-04
# Epoch 32/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1178
# Epoch 32: val_loss did not improve from 0.12332
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1183 - val_loss: 0.1278 - lr: 1.2500e-04
# Epoch 33/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1196
# Epoch 33: val_loss did not improve from 0.12332
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1184 - val_loss: 0.1322 - lr: 1.2500e-04

# %%
import hls4ml
from qkeras.utils import _add_supported_quantized_objects

co = {}
_add_supported_quantized_objects(co)
print(co)
hls_config = hls4ml.utils.config_from_keras_model(
    qmodel,
    granularity='name',
    backend='Vitis'
)
hls_model = hls4ml.converters.convert_from_keras_model(
    qmodel,
    hls_config=hls_config,
    backend='Vitis',
    output_dir='model_final',
    part='xcu250-figd2104-2L-e',
    io_type='io_stream',
)
hls_model.compile()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-oj_u34_o because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# /opt/conda/lib/python3.10/site-packages/hls4ml/converters/__init__.py:27: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# {'QInitializer': <class 'qkeras.qlayers.QInitializer'>, 'QDense': <class 'qkeras.qlayers.QDense'>, 'QConv1D': <class 'qkeras.qconvolutional.QConv1D'>, 'QConv2D': <class 'qkeras.qconvolutional.QConv2D'>, 'QConv2DTranspose': <class 'qkeras.qconvolutional.QConv2DTranspose'>, 'QSimpleRNNCell': <class 'qkeras.qrecurrent.QSimpleRNNCell'>, 'QSimpleRNN': <class 'qkeras.qrecurrent.QSimpleRNN'>, 'QLSTMCell': <class 'qkeras.qrecurrent.QLSTMCell'>, 'QLSTM': <class 'qkeras.qrecurrent.QLSTM'>, 'QGRUCell': <class 'qkeras.qrecurrent.QGRUCell'>, 'QGRU': <class 'qkeras.qrecurrent.QGRU'>, 'QBidirectional': <class 'qkeras.qrecurrent.QBidirectional'>, 'QDepthwiseConv2D': <class 'qkeras.qconvolutional.QDepthwiseConv2D'>, 'QSeparableConv1D': <class 'qkeras.qconvolutional.QSeparableConv1D'>, 'QSeparableConv2D': <class 'qkeras.qconvolutional.QSeparableConv2D'>, 'QActivation': <class 'qkeras.qlayers.QActivation'>, 'QAdaptiveActivation': <class 'qkeras.qlayers.QAdaptiveActivation'>, 'QBatchNormalization': <class 'qkeras.qnormalization.QBatchNormalization'>, 'Clip': <class 'qkeras.qlayers.Clip'>, 'quantized_bits': <class 'qkeras.quantizers.quantized_bits'>, 'bernoulli': <class 'qkeras.quantizers.bernoulli'>, 'stochastic_ternary': <class 'qkeras.quantizers.stochastic_ternary'>, 'ternary': <class 'qkeras.quantizers.ternary'>, 'stochastic_binary': <class 'qkeras.quantizers.stochastic_binary'>, 'binary': <class 'qkeras.quantizers.binary'>, 'quantized_relu': <class 'qkeras.quantizers.quantized_relu'>, 'quantized_ulaw': <class 'qkeras.quantizers.quantized_ulaw'>, 'quantized_tanh': <class 'qkeras.quantizers.quantized_tanh'>, 'quantized_sigmoid': <class 'qkeras.quantizers.quantized_sigmoid'>, 'quantized_po2': <class 'qkeras.quantizers.quantized_po2'>, 'quantized_relu_po2': <class 'qkeras.quantizers.quantized_relu_po2'>, 'QConv2DBatchnorm': <class 'qkeras.qconv2d_batchnorm.QConv2DBatchnorm'>, 'QDepthwiseConv2DBatchnorm': <class 'qkeras.qdepthwiseconv2d_batchnorm.QDepthwiseConv2DBatchnorm'>, 'QAveragePooling2D': <class 'qkeras.qpooling.QAveragePooling2D'>, 'QGlobalAveragePooling2D': <class 'qkeras.qpooling.QGlobalAveragePooling2D'>}
# Interpreting Sequential
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Layer name: q_conv1d, layer type: QConv1D, input shapes: [[None, 80, 1]], output shape: [None, 80, 32]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_1, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 40, 32]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 40, 32]], output shape: [None, 40, 32]
# Layer name: q_conv1d_2, layer type: QConv1D, input shapes: [[None, 40, 32]], output shape: [None, 40, 64]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 40, 64]], output shape: [None, 40, 64]
# Layer name: up_sampling1d, layer type: UpSampling1D, input shapes: [[None, 40, 64]], output shape: [None, 80, 64]
# Layer name: q_conv1d_3, layer type: QConv1D, input shapes: [[None, 80, 64]], output shape: [None, 80, 32]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_4, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 1]
# Layer name: q_activation_4, layer type: HardActivation, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Interpreting Sequential
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Layer name: q_conv1d, layer type: QConv1D, input shapes: [[None, 80, 1]], output shape: [None, 80, 32]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_1, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 40, 32]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 40, 32]], output shape: [None, 40, 32]
# Layer name: q_conv1d_2, layer type: QConv1D, input shapes: [[None, 40, 32]], output shape: [None, 40, 64]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 40, 64]], output shape: [None, 40, 64]
# Layer name: up_sampling1d, layer type: UpSampling1D, input shapes: [[None, 40, 64]], output shape: [None, 80, 64]
# Layer name: q_conv1d_3, layer type: QConv1D, input shapes: [[None, 80, 64]], output shape: [None, 80, 32]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_4, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 1]
# Layer name: q_activation_4, layer type: HardActivation, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Creating HLS model
# WARNING: Layer q_conv1d requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# WARNING: Config parameter "trace" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "precision" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "reuse_factor" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# Writing HLS project
# Done

# %%
import matplotlib.pyplot as plt
w = qmodel.layers[2].weights[0].numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7, 7))
plt.bar(b[:-1], h, width=b[1] - b[0])
plt.semilogy()
print(w)
print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))
# Out:
# [[[ 0.07500248 -0.02677879 -0.06993927 ... -0.20111635  0.01626479
#     0.00064804]
#   [-0.08646629 -0.19921531 -0.2009043  ...  0.09460635 -0.038979
#     0.2513415 ]
#   [ 0.14187495 -0.12219061  0.01255261 ... -0.02021583  0.00329872
#    -0.1260532 ]
#   ...
#   [-0.04513295  0.1266713  -0.00066244 ...  0.01460937 -0.3113848
#    -0.2497131 ]
#   [ 0.06569385  0.09711333 -0.13923128 ...  0.09379864 -0.09924665
#     0.0092745 ]
#   [ 0.09549186  0.1908811   0.07436689 ... -0.2162223   0.03823518
#     0.03911315]]
#
#  [[-0.25176957  0.01779215  0.18632571 ... -0.2942488   0.05535287
#     0.07924759]
#   [-0.12309194 -0.20154     0.06276793 ... -0.00788918  0.26499137
#     0.03221714]
#   [ 0.20606776 -0.24418159 -0.19968621 ... -0.00229498 -0.2177015
#    -0.05531539]
#   ...
#   [-0.04909087  0.04229382 -0.20547473 ...  0.04387847 -0.004578
#     0.05817144]
#   [-0.02248993 -0.11028146 -0.06354503 ...  0.18243279  0.1060355
#     0.1210814 ]
#   [ 0.01642614 -0.0435081   0.08976031 ...  0.01052688 -0.126903
#    -0.17891096]]
#
#  [[-0.03449165 -0.21979472 -0.30855364 ... -0.00987069  0.24147229
#    -0.05924686]
#   [ 0.16792014 -0.04305292 -0.1062137  ... -0.23145366  0.08150573
#     0.00425473]
#   [-0.08974721 -0.14328822 -0.27650627 ...  0.14011078 -0.1572456
#    -0.07656643]
#   ...
#   [ 0.11452047 -0.09033314 -0.04704688 ...  0.16155379 -0.02265157
#     0.12077607]
#   [ 0.03287268 -0.14365463 -0.18833722 ... -0.0603326   0.05600188
#    -0.1597324 ]
#   [ 0.20935953  0.10696883 -0.07285536 ...  0.02395068  0.02513078
#    -0.2039135 ]]]
# % of zeros = 0.0
