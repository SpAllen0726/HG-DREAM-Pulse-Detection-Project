# %%
import os
import numpy as np

import qkeras
from qkeras import QActivation
from qkeras import QConv1D
from qkeras.quantizers import quantized_bits, quantized_relu, quantized_tanh

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, UpSampling1D, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger

from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning

filters = 32
X_total = np.load(f"../Data/X_Data_Bank_Final.npy")
Y_total = np.load(f"../Data/Y_Data_Bank_Final.npy")
X_data = X_total[:1500,:,:]
y_data = Y_total[:1500,:,:]
TIME_STEPS = np.shape(X_data)[1]

VAL_SPLIT = 0.1

SAVE_DIR_opt = '../Extra_Files/Output_drives/1Conv_checkpoints_running'
LOG_FILE_opt = '../Extra_Files/Log_files/1Conv_3pulse_noise_tb23_opt.csv'
MODEL_NAME_TEMPLATE_opt = '../1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv_opt.h5'
checkpoint_path_opt = os.path.join(SAVE_DIR_opt, MODEL_NAME_TEMPLATE_opt)


wq = quantized_bits(8, 2, alpha=1) 
aq = quantized_relu(6) 

qmodel = Sequential([
    Input(shape=(TIME_STEPS, 1)),

    QConv1D(filters, 3, dilation_rate = 1, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),
    
    QConv1D(filters, 3, dilation_rate = 2, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),
    
    QConv1D(filters, 3, dilation_rate = 4, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),
    
    QConv1D(filters, 3, dilation_rate = 8, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),
    
    QConv1D(1, 1, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),

    QActivation("quantized_sigmoid")
    ])

qmodel.summary()

optimizer = Adam(learning_rate=0.001)
qmodel.compile(loss='binary_crossentropy', optimizer=optimizer) 


if not os.path.isdir(SAVE_DIR_opt):
    os.makedirs(SAVE_DIR_opt)

callbacks = [
    ModelCheckpoint(checkpoint_path_opt, monitor="val_loss", save_best_only=True, mode="min", verbose=1),
    CSVLogger(LOG_FILE_opt, append=True, separator=','),
    EarlyStopping(monitor="val_loss", mode="min", patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1),
]

qmodel.fit(
    X_data, y_data,
    epochs=150,                  
    shuffle=True,
    validation_split=VAL_SPLIT,
    callbacks=callbacks,
)
    
qmodel.save(f"../Models/Qdiluted_{filters}.h5")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_conv1d_10 (QConv1D)       (None, 80, 32)            128
#
#  q_activation_10 (QActivatio  (None, 80, 32)           0
#  n)
#
#  q_conv1d_11 (QConv1D)       (None, 80, 32)            3104
#
#  q_activation_11 (QActivatio  (None, 80, 32)           0
#  n)
#
#  q_conv1d_12 (QConv1D)       (None, 80, 32)            3104
#
#  q_activation_12 (QActivatio  (None, 80, 32)           0
#  n)
#
#  q_conv1d_13 (QConv1D)       (None, 80, 32)            3104
#
#  q_activation_13 (QActivatio  (None, 80, 32)           0
#  n)
#
#  q_conv1d_14 (QConv1D)       (None, 80, 1)             33
#
#  q_activation_14 (QActivatio  (None, 80, 1)            0
#  n)
#
# =================================================================
# Total params: 9,473
# Trainable params: 9,473
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.2278
# Epoch 1: val_loss improved from inf to 0.15412, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.15412.e001_deconv_opt.h5
# 43/43 [==============================] - 1s 10ms/step - loss: 0.2051 - val_loss: 0.1541 - lr: 0.0010
# Epoch 2/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1461
# Epoch 2: val_loss improved from 0.15412 to 0.14045, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.14045.e002_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1458 - val_loss: 0.1405 - lr: 0.0010
# Epoch 3/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1415
# Epoch 3: val_loss improved from 0.14045 to 0.13172, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.13172.e003_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1398 - val_loss: 0.1317 - lr: 0.0010
# Epoch 4/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1327
# Epoch 4: val_loss did not improve from 0.13172
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1328 - val_loss: 0.1395 - lr: 0.0010
# Epoch 5/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1314
# Epoch 5: val_loss improved from 0.13172 to 0.13149, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.13149.e005_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1303 - val_loss: 0.1315 - lr: 0.0010
# Epoch 6/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1278
# Epoch 6: val_loss improved from 0.13149 to 0.13044, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.13044.e006_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1278 - val_loss: 0.1304 - lr: 0.0010
# Epoch 7/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1284
# Epoch 7: val_loss improved from 0.13044 to 0.12748, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.12748.e007_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1269 - val_loss: 0.1275 - lr: 0.0010
# Epoch 8/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1257
# Epoch 8: val_loss did not improve from 0.12748
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1260 - val_loss: 0.1725 - lr: 0.0010
# Epoch 9/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1312
# Epoch 9: val_loss did not improve from 0.12748
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1284 - val_loss: 0.1382 - lr: 0.0010
# Epoch 10/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1253
# Epoch 10: val_loss did not improve from 0.12748
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1264 - val_loss: 0.1332 - lr: 0.0010
# Epoch 11/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1238
# Epoch 11: val_loss did not improve from 0.12748
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1234 - val_loss: 0.1287 - lr: 0.0010
# Epoch 12/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1221
# Epoch 12: val_loss did not improve from 0.12748
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1228 - val_loss: 0.1284 - lr: 0.0010
# Epoch 13/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1246
# Epoch 13: val_loss did not improve from 0.12748
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1206 - val_loss: 0.1283 - lr: 5.0000e-04
# Epoch 14/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1210
# Epoch 14: val_loss improved from 0.12748 to 0.12082, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.12082.e014_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1197 - val_loss: 0.1208 - lr: 5.0000e-04
# Epoch 15/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1207
# Epoch 15: val_loss did not improve from 0.12082
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1202 - val_loss: 0.1264 - lr: 5.0000e-04
# Epoch 16/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1192
# Epoch 16: val_loss did not improve from 0.12082
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1188 - val_loss: 0.1288 - lr: 5.0000e-04
# Epoch 17/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1172
# Epoch 17: val_loss did not improve from 0.12082
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1191 - val_loss: 0.1246 - lr: 5.0000e-04
# Epoch 18/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1184
# Epoch 18: val_loss did not improve from 0.12082
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1184 - val_loss: 0.1249 - lr: 5.0000e-04
# Epoch 19/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1194
# Epoch 19: val_loss improved from 0.12082 to 0.12044, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.12044.e019_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1181 - val_loss: 0.1204 - lr: 5.0000e-04
# Epoch 20/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1174
# Epoch 20: val_loss did not improve from 0.12044
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1184 - val_loss: 0.1332 - lr: 5.0000e-04
# Epoch 21/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1205
# Epoch 21: val_loss did not improve from 0.12044
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1201 - val_loss: 0.1217 - lr: 5.0000e-04
# Epoch 22/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1189
# Epoch 22: val_loss did not improve from 0.12044
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1181 - val_loss: 0.1256 - lr: 5.0000e-04
# Epoch 23/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1145
# Epoch 23: val_loss did not improve from 0.12044
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1182 - val_loss: 0.1218 - lr: 5.0000e-04
# Epoch 24/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1160
# Epoch 24: val_loss improved from 0.12044 to 0.11623, saving model to ../Extra_Files/Output_drives/1Conv_checkpoints_running/../1Conv_2pulse_noise.loss_0.11623.e024_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1162 - val_loss: 0.1162 - lr: 5.0000e-04
# Epoch 25/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1172
# Epoch 25: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1180 - val_loss: 0.1190 - lr: 5.0000e-04
# Epoch 26/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1156
# Epoch 26: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1174 - val_loss: 0.1203 - lr: 5.0000e-04
# Epoch 27/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1146
# Epoch 27: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1161 - val_loss: 0.1186 - lr: 5.0000e-04
# Epoch 28/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1162
# Epoch 28: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1156 - val_loss: 0.1293 - lr: 5.0000e-04
# Epoch 29/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1162
# Epoch 29: val_loss did not improve from 0.11623
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1148 - val_loss: 0.1199 - lr: 5.0000e-04
# Epoch 30/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1160
# Epoch 30: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1151 - val_loss: 0.1180 - lr: 2.5000e-04
# Epoch 31/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1139
# Epoch 31: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1145 - val_loss: 0.1199 - lr: 2.5000e-04
# Epoch 32/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1143
# Epoch 32: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1136 - val_loss: 0.1186 - lr: 2.5000e-04
# Epoch 33/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1124
# Epoch 33: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1130 - val_loss: 0.1237 - lr: 2.5000e-04
# Epoch 34/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1138
# Epoch 34: val_loss did not improve from 0.11623
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1128 - val_loss: 0.1234 - lr: 2.5000e-04
# Epoch 35/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1126
# Epoch 35: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1125 - val_loss: 0.1201 - lr: 1.2500e-04
# Epoch 36/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1137
# Epoch 36: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1123 - val_loss: 0.1229 - lr: 1.2500e-04
# Epoch 37/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1120
# Epoch 37: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1120 - val_loss: 0.1209 - lr: 1.2500e-04
# Epoch 38/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1129
# Epoch 38: val_loss did not improve from 0.11623
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1123 - val_loss: 0.1186 - lr: 1.2500e-04
# Epoch 39/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1112
# Epoch 39: val_loss did not improve from 0.11623
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1124 - val_loss: 0.1212 - lr: 1.2500e-04

# %%
import hls4ml
from qkeras.utils import _add_supported_quantized_objects

co = {}
_add_supported_quantized_objects(co)
print(co)
hls_config = hls4ml.utils.config_from_keras_model(
    qmodel,
    granularity='name',
    backend='Vitis'
)
hls_model = hls4ml.converters.convert_from_keras_model(
    qmodel,
    hls_config=hls_config,
    backend='Vitis',
    output_dir='../HLS_models/model_final',
    part='xcu250-figd2104-2L-e',
    io_type='io_stream',
)
hls_model.compile()
# Out:
# {'QInitializer': <class 'qkeras.qlayers.QInitializer'>, 'QDense': <class 'qkeras.qlayers.QDense'>, 'QConv1D': <class 'qkeras.qconvolutional.QConv1D'>, 'QConv2D': <class 'qkeras.qconvolutional.QConv2D'>, 'QConv2DTranspose': <class 'qkeras.qconvolutional.QConv2DTranspose'>, 'QSimpleRNNCell': <class 'qkeras.qrecurrent.QSimpleRNNCell'>, 'QSimpleRNN': <class 'qkeras.qrecurrent.QSimpleRNN'>, 'QLSTMCell': <class 'qkeras.qrecurrent.QLSTMCell'>, 'QLSTM': <class 'qkeras.qrecurrent.QLSTM'>, 'QGRUCell': <class 'qkeras.qrecurrent.QGRUCell'>, 'QGRU': <class 'qkeras.qrecurrent.QGRU'>, 'QBidirectional': <class 'qkeras.qrecurrent.QBidirectional'>, 'QDepthwiseConv2D': <class 'qkeras.qconvolutional.QDepthwiseConv2D'>, 'QSeparableConv1D': <class 'qkeras.qconvolutional.QSeparableConv1D'>, 'QSeparableConv2D': <class 'qkeras.qconvolutional.QSeparableConv2D'>, 'QActivation': <class 'qkeras.qlayers.QActivation'>, 'QAdaptiveActivation': <class 'qkeras.qlayers.QAdaptiveActivation'>, 'QBatchNormalization': <class 'qkeras.qnormalization.QBatchNormalization'>, 'Clip': <class 'qkeras.qlayers.Clip'>, 'quantized_bits': <class 'qkeras.quantizers.quantized_bits'>, 'bernoulli': <class 'qkeras.quantizers.bernoulli'>, 'stochastic_ternary': <class 'qkeras.quantizers.stochastic_ternary'>, 'ternary': <class 'qkeras.quantizers.ternary'>, 'stochastic_binary': <class 'qkeras.quantizers.stochastic_binary'>, 'binary': <class 'qkeras.quantizers.binary'>, 'quantized_relu': <class 'qkeras.quantizers.quantized_relu'>, 'quantized_ulaw': <class 'qkeras.quantizers.quantized_ulaw'>, 'quantized_tanh': <class 'qkeras.quantizers.quantized_tanh'>, 'quantized_sigmoid': <class 'qkeras.quantizers.quantized_sigmoid'>, 'quantized_po2': <class 'qkeras.quantizers.quantized_po2'>, 'quantized_relu_po2': <class 'qkeras.quantizers.quantized_relu_po2'>, 'QConv2DBatchnorm': <class 'qkeras.qconv2d_batchnorm.QConv2DBatchnorm'>, 'QDepthwiseConv2DBatchnorm': <class 'qkeras.qdepthwiseconv2d_batchnorm.QDepthwiseConv2DBatchnorm'>, 'QAveragePooling2D': <class 'qkeras.qpooling.QAveragePooling2D'>, 'QGlobalAveragePooling2D': <class 'qkeras.qpooling.QGlobalAveragePooling2D'>}
# Interpreting Sequential
# Topology:
# Layer name: input_3, layer type: InputLayer, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Layer name: q_conv1d_10, layer type: QConv1D, input shapes: [[None, 80, 1]], output shape: [None, 80, 32]
# Layer name: q_activation_10, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_11, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_activation_11, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_12, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_activation_12, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_13, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_activation_13, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_14, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 1]
# Layer name: q_activation_14, layer type: HardActivation, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Interpreting Sequential
# Topology:
# Layer name: input_3, layer type: InputLayer, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Layer name: q_conv1d_10, layer type: QConv1D, input shapes: [[None, 80, 1]], output shape: [None, 80, 32]
# Layer name: q_activation_10, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_11, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_activation_11, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_12, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_activation_12, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_13, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_activation_13, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_14, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 1]
# Layer name: q_activation_14, layer type: HardActivation, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Creating HLS model
# WARNING: Layer q_conv1d_10 requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# WARNING: Config parameter "trace" overwrites an existing attribute in layer "q_conv1d_14" (PointwiseConv1D)
# WARNING: Config parameter "precision" overwrites an existing attribute in layer "q_conv1d_14" (PointwiseConv1D)
# WARNING: Config parameter "reuse_factor" overwrites an existing attribute in layer "q_conv1d_14" (PointwiseConv1D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "q_conv1d_14" (PointwiseConv1D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "q_conv1d_14" (PointwiseConv1D)
# Writing HLS project
# Done
