# %%
import numpy as np
from tensorflow.keras.models import load_model
# Out:
# 2026-03-29 15:13:11.711038: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model_orig = load_model('unpruned_model.h5')
model_pool = load_model('unpruned_model_pooling.h5')
#model_quant = load_model('quantized_model.h5')
X_test = np.load("X_Data_Bank.npy")
Y_test = np.load("Y_Data_Bank.npy")
(NUM_EVENTS,TIME_STEPS,_) = np.shape(X_test)
# Out:
# 2026-03-29 15:13:13.827873: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
Y_test_reduced = Y_test
for i in range(NUM_EVENTS):
    for j in range(TIME_STEPS):
        if Y_test_reduced[i][j]!=0:
            Y_test_reduced[i][j]=1
y_predict_original = model_orig.predict(X_test)
'''
for i in range(NUM_EVENTS):
    for j in range(TIME_STEPS):
        if y_predict_original[i][j]!=0:
            y_predict_original[i][j]=1'''
            
predict_baseline=Y_test
test_score_baseline=model_orig.evaluate(X_test,Y_test)
y_predict_pooling=model_pool.predict(X_test)
test_score_pooling=model_pool.evaluate(X_test,Y_test)

'''for i in range(NUM_EVENTS):
    for j in range(TIME_STEPS):
        #print(y_predict_hls4ml[i][j])
        if y_predict_pooling[i][j]!=0:
            y_predict_pooling[i][j]=1'''

'''
y_predict_hls4ml = hls_model.predict((X_test_reduced))
for i in range(NUM_EVENTS):
    for j in range(TIME_STEPS):
        print(y_predict_hls4ml[i][j])
        if y_predict_hls4ml[i][j]!=0:
            y_predict_hls4ml[i][j]=1'''
# Out:
# 157/157 [==============================] - 1s 8ms/step
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0166
# 157/157 [==============================] - 1s 6ms/step
# 157/157 [==============================] - 1s 6ms/step - loss: 0.0184
# '\ny_predict_hls4ml = hls_model.predict((X_test_reduced))\nfor i in range(NUM_EVENTS):\n    for j in range(TIME_STEPS):\n        print(y_predict_hls4ml[i][j])\n        if y_predict_hls4ml[i][j]!=0:\n            y_predict_hls4ml[i][j]=1'

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
def plotROC_Comparison(Y_test_reduced,Y_predict_1, Y_predict_2):
    fpr, tpr, thresholds = roc_curve(Y_test_reduced.flatten(), Y_predict_1.flatten()) 
    roc_auc = auc(fpr, tpr)
    plt.figure()  
    fpr1, tpr1, thresholds1 = roc_curve(Y_test_reduced.flatten(), Y_predict_2.flatten())
    roc_auc1=auc(fpr1,tpr1)
    #fpr2, tpr2, thresholds2 = roc_curve(Y_test_reduced.flatten(), Y_predict_3.flatten())
    #roc_auc2=auc(fpr2,tpr2)
    plt.plot(fpr, tpr, label='ROC curve 1st model(area = %0.5f)' % roc_auc)
    plt.plot(fpr1, tpr1, label='ROC curve 2nd model(area = %0.5f)' % roc_auc1)
    #plt.plot(fpr2, tpr2, label='ROC curve 3rd model(area = %0.5f)' % roc_auc2)
    plt.plot([0, 1], [0, 1], 'k--', label='No Skill')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.show()
plotROC_Comparison(Y_test_reduced,y_predict_original,y_predict_pooling)
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-q58ljzgu because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
