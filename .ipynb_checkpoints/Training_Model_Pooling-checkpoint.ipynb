# %%
import numpy as np
import os
import tensorflow.keras.models 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten, Input, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger
from tensorflow.keras.optimizers import Adam

INPUT_FILE = 'hgdream/Sensl_FastOut_AveragePulse_1p8GHzBandwidth.feather'
SAVE_DIR = '1Conv_checkpoints_running'
LOG_FILE = '1Conv_3pulse_noise_tb23.csv'
MODEL_NAME_TEMPLATE = '1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv.h5'
SAVE_DIR2 = '1Conv_checkpoints_running2'
LOG_FILE2 = '1Conv_3pulse_noise_tb232.csv'
MODEL_NAME_TEMPLATE2 = '1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv2.h5'
SAVE_DIR3 = '1Conv_checkpoints_running3'
LOG_FILE3 = '1Conv_3pulse_noise_tb233.csv'
MODEL_NAME_TEMPLATE3 = '1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv3.h5'
NUM_EVENTS = 500
TIME_STEPS = 80 # divides width_cutoff
width_cutoff = 800
SCALE_FACTOR = 12.0 / 10.0
VAL_SPLIT = 0.1


X_data = np.load("X_Data_Bank.npy")
y_data = np.load("Y_Data_Bank.npy")

# --- Build Model ---
Train = True
if Train:
    model = Sequential([
        Input(shape=(TIME_STEPS, 1)),
        Conv1D(64, 3, activation='relu', padding='same'),
        MaxPooling1D(pool_size=2),
        MaxPooling1D(pool_size=2),
        MaxPooling1D(pool_size=2),
        Conv1D(64, 3, activation='relu', padding='same'),
        Conv1D(1, 9, activation='relu', padding='same'),
        Flatten(),
        Dense(TIME_STEPS, activation='relu')
    ])

    model.summary()

    # --- Compile Model ---
    optimizer = Adam(amsgrad=True)
    model.compile(loss='mean_squared_logarithmic_error', optimizer=optimizer) #mean_squared_logarithmic_error

    # --- Setup Checkpoints & Callbacks ---
    if not os.path.isdir(SAVE_DIR3):
        os.makedirs(SAVE_DIR3)

    checkpoint_path = os.path.join(SAVE_DIR3, MODEL_NAME_TEMPLATE3)

    callbacks = [
        ModelCheckpoint(checkpoint_path, monitor="val_loss", save_best_only=True, mode="min", verbose=1),
        EarlyStopping(monitor="val_loss", mode="min", patience=10),
        CSVLogger(LOG_FILE, append=True, separator=',')
    ]

    # --- Train Model ---
    model.fit(
        X_data, y_data,
        epochs=30,
        shuffle=True,
        validation_split=VAL_SPLIT,
        callbacks=callbacks
    )

    model.save('unpruned_model_pooling.h5')
else:
    from tensorflow.keras.models import load_model

    model = load_model('unpruned_model_pooling.h5')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_31 (Conv1D)          (None, 80, 32)            128
#
#  max_pooling1d_12 (MaxPoolin  (None, 40, 32)           0
#  g1D)
#
#  conv1d_32 (Conv1D)          (None, 40, 32)            3104
#
#  max_pooling1d_13 (MaxPoolin  (None, 20, 32)           0
#  g1D)
#
#  conv1d_33 (Conv1D)          (None, 20, 32)            3104
#
#  max_pooling1d_14 (MaxPoolin  (None, 10, 32)           0
#  g1D)
#
#  conv1d_34 (Conv1D)          (None, 10, 1)             289
#
#  flatten_6 (Flatten)         (None, 10)                0
#
#  dense_6 (Dense)             (None, 80)                880
#
# =================================================================
# Total params: 7,505
# Trainable params: 7,505
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 141/141 [==============================] - ETA: 0s - loss: 0.0293
# Epoch 1: val_loss improved from inf to 0.02801, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02801.e001_deconv3.h5
# 141/141 [==============================] - 2s 6ms/step - loss: 0.0293 - val_loss: 0.0280
# Epoch 2/30
# 134/141 [===========================>..] - ETA: 0s - loss: 0.0283
# Epoch 2: val_loss improved from 0.02801 to 0.02703, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02703.e002_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0283 - val_loss: 0.0270
# Epoch 3/30
# 133/141 [===========================>..] - ETA: 0s - loss: 0.0273
# Epoch 3: val_loss improved from 0.02703 to 0.02619, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02619.e003_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0273 - val_loss: 0.0262
# Epoch 4/30
# 132/141 [===========================>..] - ETA: 0s - loss: 0.0263
# Epoch 4: val_loss improved from 0.02619 to 0.02524, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02524.e004_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0262 - val_loss: 0.0252
# Epoch 5/30
# 140/141 [============================>.] - ETA: 0s - loss: 0.0253
# Epoch 5: val_loss improved from 0.02524 to 0.02449, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02449.e005_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0253 - val_loss: 0.0245
# Epoch 6/30
# 133/141 [===========================>..] - ETA: 0s - loss: 0.0247
# Epoch 6: val_loss improved from 0.02449 to 0.02391, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02391.e006_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0246 - val_loss: 0.0239
# Epoch 7/30
# 138/141 [============================>.] - ETA: 0s - loss: 0.0240
# Epoch 7: val_loss improved from 0.02391 to 0.02340, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02340.e007_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0240 - val_loss: 0.0234
# Epoch 8/30
# 137/141 [============================>.] - ETA: 0s - loss: 0.0236
# Epoch 8: val_loss improved from 0.02340 to 0.02316, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02316.e008_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0236 - val_loss: 0.0232
# Epoch 9/30
# 134/141 [===========================>..] - ETA: 0s - loss: 0.0233
# Epoch 9: val_loss improved from 0.02316 to 0.02302, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02302.e009_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0233 - val_loss: 0.0230
# Epoch 10/30
# 133/141 [===========================>..] - ETA: 0s - loss: 0.0231
# Epoch 10: val_loss improved from 0.02302 to 0.02282, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02282.e010_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0231 - val_loss: 0.0228
# Epoch 11/30
# 134/141 [===========================>..] - ETA: 0s - loss: 0.0229
# Epoch 11: val_loss improved from 0.02282 to 0.02272, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02272.e011_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0230 - val_loss: 0.0227
# Epoch 12/30
# 131/141 [==========================>...] - ETA: 0s - loss: 0.0228
# Epoch 12: val_loss improved from 0.02272 to 0.02266, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02266.e012_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0228 - val_loss: 0.0227
# Epoch 13/30
# 136/141 [===========================>..] - ETA: 0s - loss: 0.0227
# Epoch 13: val_loss improved from 0.02266 to 0.02250, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02250.e013_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0227 - val_loss: 0.0225
# Epoch 14/30
# 141/141 [==============================] - ETA: 0s - loss: 0.0226
# Epoch 14: val_loss improved from 0.02250 to 0.02245, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02245.e014_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0226 - val_loss: 0.0225
# Epoch 15/30
# 138/141 [============================>.] - ETA: 0s - loss: 0.0226
# Epoch 15: val_loss improved from 0.02245 to 0.02239, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02239.e015_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0226 - val_loss: 0.0224
# Epoch 16/30
# 134/141 [===========================>..] - ETA: 0s - loss: 0.0225
# Epoch 16: val_loss improved from 0.02239 to 0.02235, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02235.e016_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0225 - val_loss: 0.0223
# Epoch 17/30
# 138/141 [============================>.] - ETA: 0s - loss: 0.0224
# Epoch 17: val_loss did not improve from 0.02235
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0224 - val_loss: 0.0224
# Epoch 18/30
# 139/141 [============================>.] - ETA: 0s - loss: 0.0224
# Epoch 18: val_loss improved from 0.02235 to 0.02233, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02233.e018_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0224 - val_loss: 0.0223
# Epoch 19/30
# 136/141 [===========================>..] - ETA: 0s - loss: 0.0223
# Epoch 19: val_loss improved from 0.02233 to 0.02225, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02225.e019_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0223 - val_loss: 0.0223
# Epoch 20/30
# 138/141 [============================>.] - ETA: 0s - loss: 0.0223
# Epoch 20: val_loss improved from 0.02225 to 0.02223, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02223.e020_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 21/30
# 139/141 [============================>.] - ETA: 0s - loss: 0.0223
# Epoch 21: val_loss improved from 0.02223 to 0.02223, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02223.e021_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 22/30
# 132/141 [===========================>..] - ETA: 0s - loss: 0.0222
# Epoch 22: val_loss improved from 0.02223 to 0.02221, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02221.e022_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 23/30
# 141/141 [==============================] - ETA: 0s - loss: 0.0222
# Epoch 23: val_loss improved from 0.02221 to 0.02217, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02217.e023_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 24/30
# 137/141 [============================>.] - ETA: 0s - loss: 0.0221
# Epoch 24: val_loss did not improve from 0.02217
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0222 - val_loss: 0.0222
# Epoch 25/30
# 140/141 [============================>.] - ETA: 0s - loss: 0.0221
# Epoch 25: val_loss improved from 0.02217 to 0.02215, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02215.e025_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0221 - val_loss: 0.0222
# Epoch 26/30
# 139/141 [============================>.] - ETA: 0s - loss: 0.0221
# Epoch 26: val_loss improved from 0.02215 to 0.02211, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02211.e026_deconv3.h5
# 141/141 [==============================] - 1s 6ms/step - loss: 0.0221 - val_loss: 0.0221
# Epoch 27/30
# 138/141 [============================>.] - ETA: 0s - loss: 0.0221
# Epoch 27: val_loss improved from 0.02211 to 0.02211, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02211.e027_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0221 - val_loss: 0.0221
# Epoch 28/30
# 130/141 [==========================>...] - ETA: 0s - loss: 0.0220
# Epoch 28: val_loss improved from 0.02211 to 0.02205, saving model to 1Conv_checkpoints_running3/1Conv_2pulse_noise.loss_0.02205.e028_deconv3.h5
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 29/30
# 131/141 [==========================>...] - ETA: 0s - loss: 0.0220
# Epoch 29: val_loss did not improve from 0.02205
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 30/30
# 136/141 [===========================>..] - ETA: 0s - loss: 0.0220
# Epoch 30: val_loss did not improve from 0.02205
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0220 - val_loss: 0.0221
