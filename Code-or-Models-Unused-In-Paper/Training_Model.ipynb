# %%
import numpy as np
import os
import tensorflow.keras.models 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Flatten, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger
from tensorflow.keras.optimizers import Adam

INPUT_FILE = 'hgdream/Sensl_FastOut_AveragePulse_1p8GHzBandwidth.feather'
SAVE_DIR = '1Conv_checkpoints_running'
LOG_FILE = '1Conv_3pulse_noise_tb23.csv'
SAVE_DIR2 = '1Conv_checkpoints_running2'
LOG_FILE2 = '1Conv_3pulse_noise_tb232.csv'
MODEL_NAME_TEMPLATE = '1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv.h5'
MODEL_NAME_TEMPLATE2 = '1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv2.h5'
NUM_EVENTS = 500
TIME_STEPS = 240 # divides width_cutoff
width_cutoff = 800
SCALE_FACTOR = 12.0 / 10.0
VAL_SPLIT = 0.1


X_data = np.load("Data/X_Data_Bank_50.npy")
y_data = np.load("Data/Y_Data_Bank_50.npy")

# --- Build Model ---
model = Sequential([
    Input(shape=(TIME_STEPS, 1)),
    Conv1D(64, 3, activation='relu', padding='same'),
    Conv1D(32, 3, activation='relu', padding='same'),
    *[Conv1D(32, 3, activation='relu', padding='same') for _ in range(6)],
    Conv1D(64, 3, activation='relu', padding='same'),
    Conv1D(1, 9, activation='relu', padding='same'),
    Flatten(),
    Dense(TIME_STEPS, activation='relu')
])
model.summary()

# --- Compile Model ---
optimizer = Adam(amsgrad=True)
model.compile(loss='mean_squared_logarithmic_error', optimizer=optimizer) #mean_squared_logarithmic_error

# --- Setup Checkpoints & Callbacks ---
if not os.path.isdir(SAVE_DIR):
    os.makedirs(SAVE_DIR)

checkpoint_path = os.path.join(SAVE_DIR, MODEL_NAME_TEMPLATE)

callbacks = [
    ModelCheckpoint(checkpoint_path, monitor="val_loss", save_best_only=True, mode="min", verbose=1),
    EarlyStopping(monitor="val_loss", mode="min", patience=10),
    CSVLogger(LOG_FILE, append=True, separator=',')
]

    # --- Train Model ---
model.fit(
    X_data, y_data,
    epochs=30,
    shuffle=True,
    validation_split=VAL_SPLIT,
    callbacks=callbacks
)

model.save('unpruned_model_50.h5')
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_108 (Conv1D)         (None, 240, 64)           256
#
#  conv1d_109 (Conv1D)         (None, 240, 32)           6176
#
#  conv1d_110 (Conv1D)         (None, 240, 32)           3104
#
#  conv1d_111 (Conv1D)         (None, 240, 32)           3104
#
#  conv1d_112 (Conv1D)         (None, 240, 32)           3104
#
#  conv1d_113 (Conv1D)         (None, 240, 32)           3104
#
#  conv1d_114 (Conv1D)         (None, 240, 32)           3104
#
#  conv1d_115 (Conv1D)         (None, 240, 32)           3104
#
#  conv1d_116 (Conv1D)         (None, 240, 64)           6208
#
#  conv1d_117 (Conv1D)         (None, 240, 1)            577
#
#  flatten_12 (Flatten)        (None, 240)               0
#
#  dense_12 (Dense)            (None, 240)               57840
#
# =================================================================
# Total params: 89,681
# Trainable params: 89,681
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 562/563 [============================>.] - ETA: 0s - loss: 0.0098
# Epoch 1: val_loss improved from inf to 0.00951, saving model to 1Conv_checkpoints_running/1Conv_2pulse_noise.loss_0.00951.e001_deconv.h5
# 563/563 [==============================] - 11s 17ms/step - loss: 0.0098 - val_loss: 0.0095
# Epoch 2/30
# 561/563 [============================>.] - ETA: 0s - loss: 0.0092
# Epoch 2: val_loss improved from 0.00951 to 0.00931, saving model to 1Conv_checkpoints_running/1Conv_2pulse_noise.loss_0.00931.e002_deconv.h5
# 563/563 [==============================] - 10s 17ms/step - loss: 0.0092 - val_loss: 0.0093
# Epoch 3/30
# 561/563 [============================>.] - ETA: 0s - loss: 0.0090
# Epoch 3: val_loss improved from 0.00931 to 0.00913, saving model to 1Conv_checkpoints_running/1Conv_2pulse_noise.loss_0.00913.e003_deconv.h5
# 563/563 [==============================] - 9s 16ms/step - loss: 0.0090 - val_loss: 0.0091
# Epoch 4/30
# 561/563 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 4: val_loss improved from 0.00913 to 0.00908, saving model to 1Conv_checkpoints_running/1Conv_2pulse_noise.loss_0.00908.e004_deconv.h5
# 563/563 [==============================] - 9s 16ms/step - loss: 0.0089 - val_loss: 0.0091
# Epoch 5/30
# 562/563 [============================>.] - ETA: 0s - loss: 0.0088
# Epoch 5: val_loss improved from 0.00908 to 0.00908, saving model to 1Conv_checkpoints_running/1Conv_2pulse_noise.loss_0.00908.e005_deconv.h5
# 563/563 [==============================] - 9s 16ms/step - loss: 0.0088 - val_loss: 0.0091
# Epoch 6/30
# 563/563 [==============================] - ETA: 0s - loss: 0.0087
# Epoch 6: val_loss improved from 0.00908 to 0.00902, saving model to 1Conv_checkpoints_running/1Conv_2pulse_noise.loss_0.00902.e006_deconv.h5
# 563/563 [==============================] - 9s 16ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 7/30
# 562/563 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 7: val_loss did not improve from 0.00902
# 563/563 [==============================] - 9s 16ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 8/30
# 563/563 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 8: val_loss did not improve from 0.00902
# 563/563 [==============================] - 9s 16ms/step - loss: 0.0086 - val_loss: 0.0091
# Epoch 9/30
# 562/563 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 9: val_loss did not improve from 0.00902
# 563/563 [==============================] - 10s 18ms/step - loss: 0.0086 - val_loss: 0.0091
# Epoch 10/30
# 560/563 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 10: val_loss did not improve from 0.00902
# 563/563 [==============================] - 10s 19ms/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 11/30
# 561/563 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 11: val_loss did not improve from 0.00902
# 563/563 [==============================] - 11s 19ms/step - loss: 0.0084 - val_loss: 0.0091
# Epoch 12/30
# 561/563 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 12: val_loss did not improve from 0.00902
# 563/563 [==============================] - 9s 15ms/step - loss: 0.0084 - val_loss: 0.0092
# Epoch 13/30
# 561/563 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 13: val_loss did not improve from 0.00902
# 563/563 [==============================] - 8s 15ms/step - loss: 0.0083 - val_loss: 0.0092
# Epoch 14/30
# 561/563 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 14: val_loss did not improve from 0.00902
# 563/563 [==============================] - 8s 14ms/step - loss: 0.0083 - val_loss: 0.0093
# Epoch 15/30
# 561/563 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 15: val_loss did not improve from 0.00902
# 563/563 [==============================] - 8s 14ms/step - loss: 0.0082 - val_loss: 0.0092
# Epoch 16/30
# 560/563 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 16: val_loss did not improve from 0.00902
# 563/563 [==============================] - 8s 15ms/step - loss: 0.0082 - val_loss: 0.0093
