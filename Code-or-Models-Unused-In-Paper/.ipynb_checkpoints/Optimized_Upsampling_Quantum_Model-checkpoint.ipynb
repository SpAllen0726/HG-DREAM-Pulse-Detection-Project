# %%
import os
import numpy as np

import qkeras
from qkeras import QActivation
from qkeras import QConv1D
from qkeras.quantizers import quantized_bits, quantized_relu, quantized_tanh

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, UpSampling1D, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger



resolution = 150
X_total = np.load(f"Data/X_Data_Bank_{resolution}.npy")
Y_total = np.load(f"Data/Y_Data_Bank_{resolution}.npy")
X_data = X_total[:1500,:,:]
y_data = Y_total[:1500,:,:]
TIME_STEPS = np.shape(X_data)[1]

VAL_SPLIT = 0.1

SAVE_DIR_opt = '1Conv_checkpoints_running_opt'
LOG_FILE_opt = '1Conv_3pulse_noise_tb23_opt.csv'
MODEL_NAME_TEMPLATE_opt = '1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv_opt.h5'
checkpoint_path_opt = os.path.join(SAVE_DIR_opt, MODEL_NAME_TEMPLATE_opt)


wq = quantized_bits(8, 2, alpha=1) 
aq = quantized_relu(6) 

qmodel = Sequential([
    Input(shape=(TIME_STEPS, 1)),

    QConv1D(32, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    QConv1D(32, 3, strides=2, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    QConv1D(64, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    UpSampling1D(2),

    QConv1D(32, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),
    
    QConv1D(1, 1, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    
    QActivation("quantized_sigmoid")
    ])

qmodel.summary()


optimizer = Adam(learning_rate=0.001)
qmodel.compile(loss='binary_crossentropy', optimizer=optimizer) 


if not os.path.isdir(SAVE_DIR_opt):
    os.makedirs(SAVE_DIR_opt)

callbacks = [
    ModelCheckpoint(checkpoint_path_opt, monitor="val_loss", save_best_only=True, mode="min", verbose=1),
    CSVLogger(LOG_FILE_opt, append=True, separator=','),
    EarlyStopping(monitor="val_loss", mode="min", patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1) 
]


qmodel.fit(
    X_data, y_data,
    epochs=150,                  
    shuffle=True,
    validation_split=VAL_SPLIT,
    callbacks=callbacks
)

if not os.path.isdir("hgdream_new"):
    os.makedirs("hgdream_new")
    
qmodel.save(f"hgdream_new/quantized_model_opt_{resolution}.h5")
# Out:
# 2026-05-08 15:44:15.859081: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-08 15:44:15.903542: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-08 15:44:17.236948: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /opt/conda/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_conv1d (QConv1D)          (None, 80, 32)            128
#
#  q_activation (QActivation)  (None, 80, 32)            0
#
#  q_conv1d_1 (QConv1D)        (None, 40, 32)            3104
#
#  q_activation_1 (QActivation  (None, 40, 32)           0
#  )
#
#  q_conv1d_2 (QConv1D)        (None, 40, 64)            6208
#
#  q_activation_2 (QActivation  (None, 40, 64)           0
#  )
#
#  up_sampling1d (UpSampling1D  (None, 80, 64)           0
#  )
#
#  q_conv1d_3 (QConv1D)        (None, 80, 32)            6176
#
#  q_activation_3 (QActivation  (None, 80, 32)           0
#  )
#
#  q_conv1d_4 (QConv1D)        (None, 80, 1)             33
#
#  q_activation_4 (QActivation  (None, 80, 1)            0
#  )
#
# =================================================================
# Total params: 15,649
# Trainable params: 15,649
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 39/43 [==========================>...] - ETA: 0s - loss: 0.2600
# Epoch 1: val_loss improved from inf to 0.14948, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.14948.e001_deconv_opt.h5
# 43/43 [==============================] - 1s 13ms/step - loss: 0.2512 - val_loss: 0.1495 - lr: 0.0010
# Epoch 2/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1407
# Epoch 2: val_loss improved from 0.14948 to 0.14161, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.14161.e002_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1407 - val_loss: 0.1416 - lr: 0.0010
# Epoch 3/150
# 36/43 [========================>.....] - ETA: 0s - loss: 0.1321
# Epoch 3: val_loss improved from 0.14161 to 0.13485, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.13485.e003_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1327 - val_loss: 0.1348 - lr: 0.0010
# Epoch 4/150
# 38/43 [=========================>....] - ETA: 0s - loss: 0.1300
# Epoch 4: val_loss improved from 0.13485 to 0.12982, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12982.e004_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1305 - val_loss: 0.1298 - lr: 0.0010
# Epoch 5/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1276
# Epoch 5: val_loss improved from 0.12982 to 0.12883, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12883.e005_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1280 - val_loss: 0.1288 - lr: 0.0010
# Epoch 6/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1255
# Epoch 6: val_loss improved from 0.12883 to 0.12563, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12563.e006_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1255 - val_loss: 0.1256 - lr: 0.0010
# Epoch 7/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1234
# Epoch 7: val_loss improved from 0.12563 to 0.12372, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12372.e007_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1248 - val_loss: 0.1237 - lr: 0.0010
# Epoch 8/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1238
# Epoch 8: val_loss did not improve from 0.12372
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1238 - val_loss: 0.1271 - lr: 0.0010
# Epoch 9/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1224
# Epoch 9: val_loss did not improve from 0.12372
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1231 - val_loss: 0.1249 - lr: 0.0010
# Epoch 10/150
# 39/43 [==========================>...] - ETA: 0s - loss: 0.1228
# Epoch 10: val_loss did not improve from 0.12372
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1231 - val_loss: 0.1242 - lr: 0.0010
# Epoch 11/150
# 38/43 [=========================>....] - ETA: 0s - loss: 0.1199
# Epoch 11: val_loss did not improve from 0.12372
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1208 - val_loss: 0.1313 - lr: 0.0010
# Epoch 12/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1205
# Epoch 12: val_loss improved from 0.12372 to 0.12279, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12279.e012_deconv_opt.h5
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1205 - val_loss: 0.1228 - lr: 0.0010
# Epoch 13/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1181
# Epoch 13: val_loss did not improve from 0.12279
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1192 - val_loss: 0.1340 - lr: 0.0010
# Epoch 14/150
# 33/43 [======================>.......] - ETA: 0s - loss: 0.1199
# Epoch 14: val_loss did not improve from 0.12279
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1197 - val_loss: 0.1235 - lr: 0.0010
# Epoch 15/150
# 39/43 [==========================>...] - ETA: 0s - loss: 0.1183
# Epoch 15: val_loss did not improve from 0.12279
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1184 - val_loss: 0.1266 - lr: 0.0010
# Epoch 16/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1192
# Epoch 16: val_loss did not improve from 0.12279
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1189 - val_loss: 0.1239 - lr: 0.0010
# Epoch 17/150
# 34/43 [======================>.......] - ETA: 0s - loss: 0.1217
# Epoch 17: val_loss improved from 0.12279 to 0.12167, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12167.e017_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1202 - val_loss: 0.1217 - lr: 0.0010
# Epoch 18/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1184
# Epoch 18: val_loss did not improve from 0.12167
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1186 - val_loss: 0.1229 - lr: 0.0010
# Epoch 19/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1182
# Epoch 19: val_loss improved from 0.12167 to 0.11970, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.11970.e019_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1186 - val_loss: 0.1197 - lr: 0.0010
# Epoch 20/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1167
# Epoch 20: val_loss did not improve from 0.11970
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1168 - val_loss: 0.1276 - lr: 0.0010
# Epoch 21/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1165
# Epoch 21: val_loss did not improve from 0.11970
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1165 - val_loss: 0.1197 - lr: 0.0010
# Epoch 22/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1160
# Epoch 22: val_loss did not improve from 0.11970
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1160 - val_loss: 0.1302 - lr: 0.0010
# Epoch 23/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1152
# Epoch 23: val_loss improved from 0.11970 to 0.11955, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.11955.e023_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1152 - val_loss: 0.1195 - lr: 0.0010
# Epoch 24/150
# 38/43 [=========================>....] - ETA: 0s - loss: 0.1152
# Epoch 24: val_loss did not improve from 0.11955
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1159 - val_loss: 0.1212 - lr: 0.0010
# Epoch 25/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1149
# Epoch 25: val_loss did not improve from 0.11955
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1149 - val_loss: 0.1240 - lr: 0.0010
# Epoch 26/150
# 39/43 [==========================>...] - ETA: 0s - loss: 0.1149
# Epoch 26: val_loss did not improve from 0.11955
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1145 - val_loss: 0.1264 - lr: 0.0010
# Epoch 27/150
# 37/43 [========================>.....] - ETA: 0s - loss: 0.1147
# Epoch 27: val_loss did not improve from 0.11955
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1144 - val_loss: 0.1204 - lr: 0.0010
# Epoch 28/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1140
# Epoch 28: val_loss did not improve from 0.11955
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1143 - val_loss: 0.1232 - lr: 0.0010
# Epoch 29/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1144
# Epoch 29: val_loss did not improve from 0.11955
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1145 - val_loss: 0.1224 - lr: 5.0000e-04
# Epoch 30/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1133
# Epoch 30: val_loss did not improve from 0.11955
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1137 - val_loss: 0.1226 - lr: 5.0000e-04
# Epoch 31/150
# 39/43 [==========================>...] - ETA: 0s - loss: 0.1134
# Epoch 31: val_loss did not improve from 0.11955
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1133 - val_loss: 0.1325 - lr: 5.0000e-04
# Epoch 32/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1146
# Epoch 32: val_loss did not improve from 0.11955
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1141 - val_loss: 0.1208 - lr: 5.0000e-04
# Epoch 33/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1136
# Epoch 33: val_loss did not improve from 0.11955
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1122 - val_loss: 0.1217 - lr: 5.0000e-04
# Epoch 34/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1129
# Epoch 34: val_loss improved from 0.11955 to 0.11937, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.11937.e034_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1123 - val_loss: 0.1194 - lr: 2.5000e-04
# Epoch 35/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1122
# Epoch 35: val_loss did not improve from 0.11937
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1119 - val_loss: 0.1253 - lr: 2.5000e-04
# Epoch 36/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1113
# Epoch 36: val_loss did not improve from 0.11937
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1112 - val_loss: 0.1318 - lr: 2.5000e-04
# Epoch 37/150
# 38/43 [=========================>....] - ETA: 0s - loss: 0.1113
# Epoch 37: val_loss did not improve from 0.11937
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1117 - val_loss: 0.1218 - lr: 2.5000e-04
# Epoch 38/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1101
# Epoch 38: val_loss did not improve from 0.11937
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1119 - val_loss: 0.1250 - lr: 2.5000e-04
# Epoch 39/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1116
# Epoch 39: val_loss did not improve from 0.11937
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1118 - val_loss: 0.1259 - lr: 2.5000e-04
# Epoch 40/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1112
# Epoch 40: val_loss did not improve from 0.11937
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1113 - val_loss: 0.1238 - lr: 1.2500e-04
# Epoch 41/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1118
# Epoch 41: val_loss did not improve from 0.11937
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1111 - val_loss: 0.1384 - lr: 1.2500e-04
# Epoch 42/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1116
# Epoch 42: val_loss did not improve from 0.11937
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1115 - val_loss: 0.1238 - lr: 1.2500e-04
# Epoch 43/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1107
# Epoch 43: val_loss did not improve from 0.11937
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1106 - val_loss: 0.1236 - lr: 1.2500e-04
# Epoch 44/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1103
# Epoch 44: val_loss improved from 0.11937 to 0.11863, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.11863.e044_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1110 - val_loss: 0.1186 - lr: 1.2500e-04
# Epoch 45/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1104
# Epoch 45: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1109 - val_loss: 0.1241 - lr: 1.2500e-04
# Epoch 46/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1108
# Epoch 46: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1105 - val_loss: 0.1230 - lr: 1.2500e-04
# Epoch 47/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1103
# Epoch 47: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1106 - val_loss: 0.1241 - lr: 1.2500e-04
# Epoch 48/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1115
# Epoch 48: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1121 - val_loss: 0.1229 - lr: 1.2500e-04
# Epoch 49/150
# 31/43 [====================>.........] - ETA: 0s - loss: 0.1102
# Epoch 49: val_loss did not improve from 0.11863
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1113 - val_loss: 0.1212 - lr: 1.2500e-04
# Epoch 50/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1105
# Epoch 50: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1108 - val_loss: 0.1278 - lr: 6.2500e-05
# Epoch 51/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1117
# Epoch 51: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1117 - val_loss: 0.1263 - lr: 6.2500e-05
# Epoch 52/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1108
# Epoch 52: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1107 - val_loss: 0.1268 - lr: 6.2500e-05
# Epoch 53/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1114
# Epoch 53: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1116 - val_loss: 0.1253 - lr: 6.2500e-05
# Epoch 54/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1115
# Epoch 54: val_loss did not improve from 0.11863
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1116 - val_loss: 0.1220 - lr: 6.2500e-05
# Epoch 55/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1103
# Epoch 55: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1104 - val_loss: 0.1243 - lr: 3.1250e-05
# Epoch 56/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1106
# Epoch 56: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1105 - val_loss: 0.1281 - lr: 3.1250e-05
# Epoch 57/150
# 30/43 [===================>..........] - ETA: 0s - loss: 0.1092
# Epoch 57: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1102 - val_loss: 0.1245 - lr: 3.1250e-05
# Epoch 58/150
# 39/43 [==========================>...] - ETA: 0s - loss: 0.1100
# Epoch 58: val_loss did not improve from 0.11863
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1103 - val_loss: 0.1249 - lr: 3.1250e-05
# Epoch 59/150
# 38/43 [=========================>....] - ETA: 0s - loss: 0.1111
# Epoch 59: val_loss did not improve from 0.11863
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1113 - val_loss: 0.1254 - lr: 3.1250e-05

# %%
import hls4ml
from qkeras.utils import _add_supported_quantized_objects

co = {}
_add_supported_quantized_objects(co)
print(co)
hls_config = hls4ml.utils.config_from_keras_model(
    qmodel,
    granularity='name',
    backend='Vitis'
)
hls_model = hls4ml.converters.convert_from_keras_model(
    qmodel,
    hls_config=hls_config,
    backend='Vitis',
    output_dir='model_final',
    part='xcu250-figd2104-2L-e',
    io_type='io_stream',
)
hls_model.compile()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-oj_u34_o because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# /opt/conda/lib/python3.10/site-packages/hls4ml/converters/__init__.py:27: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# {'QInitializer': <class 'qkeras.qlayers.QInitializer'>, 'QDense': <class 'qkeras.qlayers.QDense'>, 'QConv1D': <class 'qkeras.qconvolutional.QConv1D'>, 'QConv2D': <class 'qkeras.qconvolutional.QConv2D'>, 'QConv2DTranspose': <class 'qkeras.qconvolutional.QConv2DTranspose'>, 'QSimpleRNNCell': <class 'qkeras.qrecurrent.QSimpleRNNCell'>, 'QSimpleRNN': <class 'qkeras.qrecurrent.QSimpleRNN'>, 'QLSTMCell': <class 'qkeras.qrecurrent.QLSTMCell'>, 'QLSTM': <class 'qkeras.qrecurrent.QLSTM'>, 'QGRUCell': <class 'qkeras.qrecurrent.QGRUCell'>, 'QGRU': <class 'qkeras.qrecurrent.QGRU'>, 'QBidirectional': <class 'qkeras.qrecurrent.QBidirectional'>, 'QDepthwiseConv2D': <class 'qkeras.qconvolutional.QDepthwiseConv2D'>, 'QSeparableConv1D': <class 'qkeras.qconvolutional.QSeparableConv1D'>, 'QSeparableConv2D': <class 'qkeras.qconvolutional.QSeparableConv2D'>, 'QActivation': <class 'qkeras.qlayers.QActivation'>, 'QAdaptiveActivation': <class 'qkeras.qlayers.QAdaptiveActivation'>, 'QBatchNormalization': <class 'qkeras.qnormalization.QBatchNormalization'>, 'Clip': <class 'qkeras.qlayers.Clip'>, 'quantized_bits': <class 'qkeras.quantizers.quantized_bits'>, 'bernoulli': <class 'qkeras.quantizers.bernoulli'>, 'stochastic_ternary': <class 'qkeras.quantizers.stochastic_ternary'>, 'ternary': <class 'qkeras.quantizers.ternary'>, 'stochastic_binary': <class 'qkeras.quantizers.stochastic_binary'>, 'binary': <class 'qkeras.quantizers.binary'>, 'quantized_relu': <class 'qkeras.quantizers.quantized_relu'>, 'quantized_ulaw': <class 'qkeras.quantizers.quantized_ulaw'>, 'quantized_tanh': <class 'qkeras.quantizers.quantized_tanh'>, 'quantized_sigmoid': <class 'qkeras.quantizers.quantized_sigmoid'>, 'quantized_po2': <class 'qkeras.quantizers.quantized_po2'>, 'quantized_relu_po2': <class 'qkeras.quantizers.quantized_relu_po2'>, 'QConv2DBatchnorm': <class 'qkeras.qconv2d_batchnorm.QConv2DBatchnorm'>, 'QDepthwiseConv2DBatchnorm': <class 'qkeras.qdepthwiseconv2d_batchnorm.QDepthwiseConv2DBatchnorm'>, 'QAveragePooling2D': <class 'qkeras.qpooling.QAveragePooling2D'>, 'QGlobalAveragePooling2D': <class 'qkeras.qpooling.QGlobalAveragePooling2D'>}
# Interpreting Sequential
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Layer name: q_conv1d, layer type: QConv1D, input shapes: [[None, 80, 1]], output shape: [None, 80, 32]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_1, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 40, 32]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 40, 32]], output shape: [None, 40, 32]
# Layer name: q_conv1d_2, layer type: QConv1D, input shapes: [[None, 40, 32]], output shape: [None, 40, 64]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 40, 64]], output shape: [None, 40, 64]
# Layer name: up_sampling1d, layer type: UpSampling1D, input shapes: [[None, 40, 64]], output shape: [None, 80, 64]
# Layer name: q_conv1d_3, layer type: QConv1D, input shapes: [[None, 80, 64]], output shape: [None, 80, 32]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_4, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 1]
# Layer name: q_activation_4, layer type: HardActivation, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Interpreting Sequential
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Layer name: q_conv1d, layer type: QConv1D, input shapes: [[None, 80, 1]], output shape: [None, 80, 32]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_1, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 40, 32]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 40, 32]], output shape: [None, 40, 32]
# Layer name: q_conv1d_2, layer type: QConv1D, input shapes: [[None, 40, 32]], output shape: [None, 40, 64]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 40, 64]], output shape: [None, 40, 64]
# Layer name: up_sampling1d, layer type: UpSampling1D, input shapes: [[None, 40, 64]], output shape: [None, 80, 64]
# Layer name: q_conv1d_3, layer type: QConv1D, input shapes: [[None, 80, 64]], output shape: [None, 80, 32]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_4, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 1]
# Layer name: q_activation_4, layer type: HardActivation, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Creating HLS model
# WARNING: Layer q_conv1d requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# WARNING: Config parameter "trace" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "precision" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "reuse_factor" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# Writing HLS project
# Done

# %%
import matplotlib.pyplot as plt
w = qmodel.layers[2].weights[0].numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7, 7))
plt.bar(b[:-1], h, width=b[1] - b[0])
plt.semilogy()
print(w)
print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))
# Out:
# [[[-0.06607342  0.06994843  0.11664541 ...  0.04976555  0.00564602
#    -0.00795602]
#   [-0.2037177  -0.08577628  0.10791223 ... -0.14045477  0.04015488
#     0.08332631]
#   [ 0.09804488  0.13945366 -0.10274836 ... -0.03733756  0.0186969
#    -0.15788625]
#   ...
#   [ 0.2701006  -0.03650042  0.13458632 ... -0.01308412  0.13144813
#     0.21805106]
#   [-0.14291444  0.04910483 -0.2649296  ... -0.09721101 -0.03830449
#    -0.2492974 ]
#   [-0.16432558  0.22737364 -0.17607556 ... -0.268632    0.06694672
#     0.14015421]]
#
#  [[ 0.14172614  0.0424509  -0.17081857 ... -0.00998121 -0.14173047
#    -0.03814515]
#   [ 0.08288424  0.04709306 -0.04517011 ...  0.03506508 -0.05034686
#     0.08624686]
#   [-0.00467892  0.06749059  0.2507949  ... -0.29981557  0.14436397
#    -0.19083549]
#   ...
#   [ 0.03415073 -0.0336691  -0.20480731 ...  0.26279595 -0.01129646
#     0.16080764]
#   [-0.03177512  0.08241314 -0.24685447 ...  0.02003681  0.11865167
#     0.13944523]
#   [-0.14214328  0.08539635  0.03599301 ... -0.14847247  0.12863238
#     0.15407053]]
#
#  [[ 0.05099038  0.2761996  -0.03785034 ...  0.11214657 -0.05468878
#     0.18575333]
#   [ 0.20321482 -0.203955    0.13197911 ...  0.15490644  0.0024148
#    -0.16947883]
#   [ 0.25135395  0.0089451  -0.0240098  ... -0.09463636  0.2275792
#    -0.1055268 ]
#   ...
#   [ 0.17199981  0.06918915 -0.05177318 ... -0.12387494  0.1952058
#    -0.02666335]
#   [-0.07017673 -0.20174283  0.12804541 ...  0.07245394  0.00765572
#    -0.07674379]
#   [-0.2504437   0.0833636   0.2140575  ... -0.13389371  0.11913714
#     0.10492139]]]
# % of zeros = 0.0
