# %%
import os
import numpy as np

import qkeras
from qkeras import QActivation
from qkeras import QConv1D
from qkeras.quantizers import quantized_bits, quantized_relu, quantized_tanh

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, UpSampling1D, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger

from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning

resolution = 150
X_total = np.load(f"Data/X_Data_Bank_{resolution}.npy")
Y_total = np.load(f"Data/Y_Data_Bank_{resolution}.npy")
X_data = X_total[:1500,:,:]
y_data = Y_total[:1500,:,:]
TIME_STEPS = np.shape(X_data)[1]

VAL_SPLIT = 0.1

SAVE_DIR_opt = '1Conv_checkpoints_running_opt'
LOG_FILE_opt = '1Conv_3pulse_noise_tb23_opt.csv'
MODEL_NAME_TEMPLATE_opt = '1Conv_2pulse_noise.loss_{val_loss:01.5f}.e{epoch:03d}_deconv_opt.h5'
checkpoint_path_opt = os.path.join(SAVE_DIR_opt, MODEL_NAME_TEMPLATE_opt)


wq = quantized_bits(8, 2, alpha=1) 
aq = quantized_relu(6) 

qmodel = Sequential([
    Input(shape=(TIME_STEPS, 1)),

    QConv1D(32, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    QConv1D(32, 3, strides=2, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    QConv1D(64, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),

    UpSampling1D(2),

    QConv1D(32, 3, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    QActivation(aq),
    
    QConv1D(1, 1, padding='same',
            kernel_quantizer=wq, bias_quantizer=wq),
    
    QActivation("quantized_sigmoid")
    ])

qmodel.summary()


pruning_params = {"pruning_schedule": pruning_schedule.ConstantSparsity(0.75, begin_step=2000, frequency=100)}
qmodel = prune.prune_low_magnitude(qmodel, **pruning_params)


optimizer = Adam(learning_rate=0.001)
qmodel.compile(loss='binary_crossentropy', optimizer=optimizer) 


if not os.path.isdir(SAVE_DIR_opt):
    os.makedirs(SAVE_DIR_opt)
    
callbacks = [
    ModelCheckpoint(checkpoint_path_opt, monitor="val_loss", save_best_only=True, mode="min", verbose=1),
    CSVLogger(LOG_FILE_opt, append=True, separator=','),
    EarlyStopping(monitor="val_loss", mode="min", patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1) 
]
callbacks.append(pruning_callbacks.UpdatePruningStep())

qmodel.fit(
    X_data, y_data,
    epochs=150,                  
    shuffle=True,
    validation_split=VAL_SPLIT,
    callbacks=callbacks
)

if not os.path.isdir("hgdream_new"):
    os.makedirs("hgdream_new")

qmodel = strip_pruning(qmodel)
qmodel.save(f"hgdream_new/quantized_model_opt_{resolution}_pruned.h5")
# Out:
# 2026-05-08 15:28:28.614659: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-08 15:28:28.653301: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-08 15:28:29.749012: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /opt/conda/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_conv1d (QConv1D)          (None, 80, 32)            128
#
#  q_activation (QActivation)  (None, 80, 32)            0
#
#  q_conv1d_1 (QConv1D)        (None, 40, 32)            3104
#
#  q_activation_1 (QActivation  (None, 40, 32)           0
#  )
#
#  q_conv1d_2 (QConv1D)        (None, 40, 64)            6208
#
#  q_activation_2 (QActivation  (None, 40, 64)           0
#  )
#
#  up_sampling1d (UpSampling1D  (None, 80, 64)           0
#  )
#
#  q_conv1d_3 (QConv1D)        (None, 80, 32)            6176
#
#  q_activation_3 (QActivation  (None, 80, 32)           0
#  )
#
#  q_conv1d_4 (QConv1D)        (None, 80, 1)             33
#
#  q_activation_4 (QActivation  (None, 80, 1)            0
#  )
#
# =================================================================
# Total params: 15,649
# Trainable params: 15,649
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.2274
# Epoch 1: val_loss improved from inf to 0.14944, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.14944.e001_deconv_opt.h5
# 43/43 [==============================] - 2s 11ms/step - loss: 0.2233 - val_loss: 0.1494 - lr: 0.0010
# Epoch 2/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1407
# Epoch 2: val_loss improved from 0.14944 to 0.13933, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.13933.e002_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1410 - val_loss: 0.1393 - lr: 0.0010
# Epoch 3/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1332
# Epoch 3: val_loss improved from 0.13933 to 0.13340, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.13340.e003_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1333 - val_loss: 0.1334 - lr: 0.0010
# Epoch 4/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1293
# Epoch 4: val_loss improved from 0.13340 to 0.13096, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.13096.e004_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1293 - val_loss: 0.1310 - lr: 0.0010
# Epoch 5/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1288
# Epoch 5: val_loss did not improve from 0.13096
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1288 - val_loss: 0.1313 - lr: 0.0010
# Epoch 6/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1267
# Epoch 6: val_loss did not improve from 0.13096
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1265 - val_loss: 0.1329 - lr: 0.0010
# Epoch 7/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1248
# Epoch 7: val_loss did not improve from 0.13096
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1252 - val_loss: 0.1546 - lr: 0.0010
# Epoch 8/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1260
# Epoch 8: val_loss improved from 0.13096 to 0.12865, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12865.e008_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1258 - val_loss: 0.1286 - lr: 0.0010
# Epoch 9/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1229
# Epoch 9: val_loss improved from 0.12865 to 0.12651, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12651.e009_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1229 - val_loss: 0.1265 - lr: 0.0010
# Epoch 10/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1242
# Epoch 10: val_loss improved from 0.12651 to 0.12437, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12437.e010_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1242 - val_loss: 0.1244 - lr: 0.0010
# Epoch 11/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1230
# Epoch 11: val_loss did not improve from 0.12437
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1228 - val_loss: 0.1275 - lr: 0.0010
# Epoch 12/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1242
# Epoch 12: val_loss did not improve from 0.12437
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1225 - val_loss: 0.1292 - lr: 0.0010
# Epoch 13/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1219
# Epoch 13: val_loss did not improve from 0.12437
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1221 - val_loss: 0.1293 - lr: 0.0010
# Epoch 14/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1204
# Epoch 14: val_loss did not improve from 0.12437
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1204 - val_loss: 0.1269 - lr: 0.0010
# Epoch 15/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1208
# Epoch 15: val_loss did not improve from 0.12437
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1208 - val_loss: 0.1274 - lr: 0.0010
# Epoch 16/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1204
# Epoch 16: val_loss did not improve from 0.12437
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1204 - val_loss: 0.1267 - lr: 5.0000e-04
# Epoch 17/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1191
# Epoch 17: val_loss did not improve from 0.12437
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1191 - val_loss: 0.1254 - lr: 5.0000e-04
# Epoch 18/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1185
# Epoch 18: val_loss did not improve from 0.12437
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1187 - val_loss: 0.1291 - lr: 5.0000e-04
# Epoch 19/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1187
# Epoch 19: val_loss did not improve from 0.12437
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1184 - val_loss: 0.1276 - lr: 5.0000e-04
# Epoch 20/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1198
# Epoch 20: val_loss improved from 0.12437 to 0.12389, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12389.e020_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1181 - val_loss: 0.1239 - lr: 5.0000e-04
# Epoch 21/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1190
# Epoch 21: val_loss did not improve from 0.12389
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1189 - val_loss: 0.1261 - lr: 5.0000e-04
# Epoch 22/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1184
# Epoch 22: val_loss did not improve from 0.12389
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1182 - val_loss: 0.1262 - lr: 5.0000e-04
# Epoch 23/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1178
# Epoch 23: val_loss improved from 0.12389 to 0.12216, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12216.e023_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1177 - val_loss: 0.1222 - lr: 5.0000e-04
# Epoch 24/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1182
# Epoch 24: val_loss did not improve from 0.12216
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1184 - val_loss: 0.1230 - lr: 5.0000e-04
# Epoch 25/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1189
# Epoch 25: val_loss improved from 0.12216 to 0.12135, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.12135.e025_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1187 - val_loss: 0.1214 - lr: 5.0000e-04
# Epoch 26/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1173
# Epoch 26: val_loss did not improve from 0.12135
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1172 - val_loss: 0.1233 - lr: 5.0000e-04
# Epoch 27/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1180
# Epoch 27: val_loss did not improve from 0.12135
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1180 - val_loss: 0.1234 - lr: 5.0000e-04
# Epoch 28/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1146
# Epoch 28: val_loss did not improve from 0.12135
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1173 - val_loss: 0.1257 - lr: 5.0000e-04
# Epoch 29/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1175
# Epoch 29: val_loss did not improve from 0.12135
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1170 - val_loss: 0.1250 - lr: 5.0000e-04
# Epoch 30/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1175
# Epoch 30: val_loss did not improve from 0.12135
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1175 - val_loss: 0.1296 - lr: 5.0000e-04
# Epoch 31/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1172
# Epoch 31: val_loss did not improve from 0.12135
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1167 - val_loss: 0.1244 - lr: 2.5000e-04
# Epoch 32/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1165
# Epoch 32: val_loss improved from 0.12135 to 0.11974, saving model to 1Conv_checkpoints_running_opt/1Conv_2pulse_noise.loss_0.11974.e032_deconv_opt.h5
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1166 - val_loss: 0.1197 - lr: 2.5000e-04
# Epoch 33/150
# 29/43 [===================>..........] - ETA: 0s - loss: 0.1153
# Epoch 33: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1162 - val_loss: 0.1234 - lr: 2.5000e-04
# Epoch 34/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1186
# Epoch 34: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1183 - val_loss: 0.1222 - lr: 2.5000e-04
# Epoch 35/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1167
# Epoch 35: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1165 - val_loss: 0.1212 - lr: 2.5000e-04
# Epoch 36/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1166
# Epoch 36: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1166 - val_loss: 0.1240 - lr: 2.5000e-04
# Epoch 37/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1169
# Epoch 37: val_loss did not improve from 0.11974
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1169 - val_loss: 0.1220 - lr: 2.5000e-04
# Epoch 38/150
# 41/43 [===========================>..] - ETA: 0s - loss: 0.1157
# Epoch 38: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1153 - val_loss: 0.1231 - lr: 1.2500e-04
# Epoch 39/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1164
# Epoch 39: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1164 - val_loss: 0.1248 - lr: 1.2500e-04
# Epoch 40/150
# 37/43 [========================>.....] - ETA: 0s - loss: 0.1176
# Epoch 40: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1171 - val_loss: 0.1216 - lr: 1.2500e-04
# Epoch 41/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1160
# Epoch 41: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1160 - val_loss: 0.1235 - lr: 1.2500e-04
# Epoch 42/150
# 38/43 [=========================>....] - ETA: 0s - loss: 0.1150
# Epoch 42: val_loss did not improve from 0.11974
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 43/43 [==============================] - 0s 5ms/step - loss: 0.1154 - val_loss: 0.1221 - lr: 1.2500e-04
# Epoch 43/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1153
# Epoch 43: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1155 - val_loss: 0.1272 - lr: 6.2500e-05
# Epoch 44/150
# 43/43 [==============================] - ETA: 0s - loss: 0.1151
# Epoch 44: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1151 - val_loss: 0.1230 - lr: 6.2500e-05
# Epoch 45/150
# 40/43 [==========================>...] - ETA: 0s - loss: 0.1148
# Epoch 45: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1153 - val_loss: 0.1232 - lr: 6.2500e-05
# Epoch 46/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1151
# Epoch 46: val_loss did not improve from 0.11974
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1151 - val_loss: 0.1254 - lr: 6.2500e-05
# Epoch 47/150
# 42/43 [============================>.] - ETA: 0s - loss: 0.1634
# Epoch 47: val_loss did not improve from 0.11974
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 43/43 [==============================] - 0s 4ms/step - loss: 0.1635 - val_loss: 0.1828 - lr: 6.2500e-05
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
import hls4ml
from qkeras.utils import _add_supported_quantized_objects

co = {}
_add_supported_quantized_objects(co)
print(co)
hls_config = hls4ml.utils.config_from_keras_model(
    qmodel,
    granularity='name',
    backend='Vitis'
)
hls_model = hls4ml.converters.convert_from_keras_model(
    qmodel,
    hls_config=hls_config,
    backend='Vitis',
    output_dir='model_final',
    part='xcu250-figd2104-2L-e',
    io_type='io_stream',
)
hls_model.compile()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-b1n6yav0 because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# {'QInitializer': <class 'qkeras.qlayers.QInitializer'>, 'QDense': <class 'qkeras.qlayers.QDense'>, 'QConv1D': <class 'qkeras.qconvolutional.QConv1D'>, 'QConv2D': <class 'qkeras.qconvolutional.QConv2D'>, 'QConv2DTranspose': <class 'qkeras.qconvolutional.QConv2DTranspose'>, 'QSimpleRNNCell': <class 'qkeras.qrecurrent.QSimpleRNNCell'>, 'QSimpleRNN': <class 'qkeras.qrecurrent.QSimpleRNN'>, 'QLSTMCell': <class 'qkeras.qrecurrent.QLSTMCell'>, 'QLSTM': <class 'qkeras.qrecurrent.QLSTM'>, 'QGRUCell': <class 'qkeras.qrecurrent.QGRUCell'>, 'QGRU': <class 'qkeras.qrecurrent.QGRU'>, 'QBidirectional': <class 'qkeras.qrecurrent.QBidirectional'>, 'QDepthwiseConv2D': <class 'qkeras.qconvolutional.QDepthwiseConv2D'>, 'QSeparableConv1D': <class 'qkeras.qconvolutional.QSeparableConv1D'>, 'QSeparableConv2D': <class 'qkeras.qconvolutional.QSeparableConv2D'>, 'QActivation': <class 'qkeras.qlayers.QActivation'>, 'QAdaptiveActivation': <class 'qkeras.qlayers.QAdaptiveActivation'>, 'QBatchNormalization': <class 'qkeras.qnormalization.QBatchNormalization'>, 'Clip': <class 'qkeras.qlayers.Clip'>, 'quantized_bits': <class 'qkeras.quantizers.quantized_bits'>, 'bernoulli': <class 'qkeras.quantizers.bernoulli'>, 'stochastic_ternary': <class 'qkeras.quantizers.stochastic_ternary'>, 'ternary': <class 'qkeras.quantizers.ternary'>, 'stochastic_binary': <class 'qkeras.quantizers.stochastic_binary'>, 'binary': <class 'qkeras.quantizers.binary'>, 'quantized_relu': <class 'qkeras.quantizers.quantized_relu'>, 'quantized_ulaw': <class 'qkeras.quantizers.quantized_ulaw'>, 'quantized_tanh': <class 'qkeras.quantizers.quantized_tanh'>, 'quantized_sigmoid': <class 'qkeras.quantizers.quantized_sigmoid'>, 'quantized_po2': <class 'qkeras.quantizers.quantized_po2'>, 'quantized_relu_po2': <class 'qkeras.quantizers.quantized_relu_po2'>, 'QConv2DBatchnorm': <class 'qkeras.qconv2d_batchnorm.QConv2DBatchnorm'>, 'QDepthwiseConv2DBatchnorm': <class 'qkeras.qdepthwiseconv2d_batchnorm.QDepthwiseConv2DBatchnorm'>, 'QAveragePooling2D': <class 'qkeras.qpooling.QAveragePooling2D'>, 'QGlobalAveragePooling2D': <class 'qkeras.qpooling.QGlobalAveragePooling2D'>}
# Interpreting Sequential
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Layer name: q_conv1d, layer type: QConv1D, input shapes: [[None, 80, 1]], output shape: [None, 80, 32]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_1, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 40, 32]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 40, 32]], output shape: [None, 40, 32]
# Layer name: q_conv1d_2, layer type: QConv1D, input shapes: [[None, 40, 32]], output shape: [None, 40, 64]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 40, 64]], output shape: [None, 40, 64]
# Layer name: up_sampling1d, layer type: UpSampling1D, input shapes: [[None, 40, 64]], output shape: [None, 80, 64]
# Layer name: q_conv1d_3, layer type: QConv1D, input shapes: [[None, 80, 64]], output shape: [None, 80, 32]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_4, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 1]
# Layer name: q_activation_4, layer type: HardActivation, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Interpreting Sequential
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Layer name: q_conv1d, layer type: QConv1D, input shapes: [[None, 80, 1]], output shape: [None, 80, 32]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_1, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 40, 32]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 40, 32]], output shape: [None, 40, 32]
# Layer name: q_conv1d_2, layer type: QConv1D, input shapes: [[None, 40, 32]], output shape: [None, 40, 64]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 40, 64]], output shape: [None, 40, 64]
# Layer name: up_sampling1d, layer type: UpSampling1D, input shapes: [[None, 40, 64]], output shape: [None, 80, 64]
# Layer name: q_conv1d_3, layer type: QConv1D, input shapes: [[None, 80, 64]], output shape: [None, 80, 32]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 80, 32]], output shape: [None, 80, 32]
# Layer name: q_conv1d_4, layer type: QConv1D, input shapes: [[None, 80, 32]], output shape: [None, 80, 1]
# Layer name: q_activation_4, layer type: HardActivation, input shapes: [[None, 80, 1]], output shape: [None, 80, 1]
# Creating HLS model
# WARNING: Layer q_conv1d requires "dataflow" pipeline style. Switching to "dataflow" pipeline style.
# WARNING: Config parameter "trace" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "precision" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "reuse_factor" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "parallelization_factor" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# WARNING: Config parameter "conv_implementation" overwrites an existing attribute in layer "q_conv1d_4" (PointwiseConv1D)
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /opt/conda/lib/python3.10/site-packages/hls4ml/converters/__init__.py:27: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)
# Done

# %%
w = qmodel.layers[0].weights[0].numpy()
h, b = np.histogram(w, bins=100)
plt.figure(figsize=(7, 7))
plt.bar(b[:-1], h, width=b[1] - b[0])
plt.semilogy()
print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 w = qmodel.layers[0].weights[0].numpy()
#       2 h, b = np.histogram(w, bins=100)
#       3 plt.figure(figsize=(7, 7))
#
# NameError: name 'qmodel' is not defined
